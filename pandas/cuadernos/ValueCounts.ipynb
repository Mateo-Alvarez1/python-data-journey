# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Mateo Alvarez\OneDrive\Documentos\DATASET_FACTORY\output\Movimientos_Almacen\mining_warehouse_movements.csv',
    sep=';',)
df
# Out:
#         movement_id movement_date  year  month day_of_week  \
# 0       MOV-0000001     2/10/2023  2023     10       Lunes
# 1       MOV-0000002     2/10/2023  2023     10       Lunes
# 2       MOV-0000003     2/10/2023  2023     10       Lunes
# 3       MOV-0000004     2/10/2023  2023     10       Lunes
# 4       MOV-0000005     2/10/2023  2023     10       Lunes
# ...             ...           ...   ...    ...         ...
# 129088  MOV-0129089     14/9/2026  2026      9       Lunes
# 129089  MOV-0129090     14/9/2026  2026      9       Lunes
# 129090  MOV-0129091     14/9/2026  2026      9       Lunes
# 129091  MOV-0129092     14/9/2026  2026      9       Lunes
# 129092  MOV-0129093     14/9/2026  2026      9       Lunes
#
#                 movement_type movement_direction          reference_type  \
# 0        Transferencia Salida             Salida  Orden de Transferencia
# 1             Despacho a Mina             Salida          Pedido de Mina
# ...

# %% [markdown]
# # Value Counts

# %%
# Contar los elementos por columna

#Funcion len()
len(df['year'])
# Funcion Count()
df['year'].count()
# Contar elementos por cateforia
df['year'].value_counts()
# Out:
# year
# 2024    43982
# 2025    43924
# 2026    30619
# 2023    10568
# Name: count, dtype: int64

# %%
# Obtener frecuencia relativa (dividir todos los valores entre la suma de los elementos)
# Sacamos porcentjae que ocupa cada uno del total
df['year'].value_counts(normalize=True)
# Out:
# year
# 2024    0.340700
# 2025    0.340251
# 2026    0.237186
# 2023    0.081863
# Name: proportion, dtype: float64

# %%
# Calcular reference_type por categoria
df['reference_type'].value_counts()
# Obtener el porcentaje que ocupa cada categoria en el total
df['reference_type'].value_counts(normalize = True)
# Out:
# reference_type
# Pedido de Mina            0.451574
# Orden de Transferencia    0.351622
# Orden de Compra           0.192032
# Ajuste de Inventario      0.004384
# Nota de Devolución        0.000387
# Name: proportion, dtype: float64
