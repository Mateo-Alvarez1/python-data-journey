# %% [markdown]
# # Ordenar un Dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Mateo Alvarez\OneDrive\Documentos\DATASET_FACTORY\output\Movimientos_Almacen\mining_warehouse_movements.csv',
    sep=';',)
df
# Out:
#         movement_id movement_date  year  month day_of_week  \
# 0       MOV-0000001     2/10/2023  2023     10       Lunes
# 1       MOV-0000002     2/10/2023  2023     10       Lunes
# 2       MOV-0000003     2/10/2023  2023     10       Lunes
# 3       MOV-0000004     2/10/2023  2023     10       Lunes
# 4       MOV-0000005     2/10/2023  2023     10       Lunes
# ...             ...           ...   ...    ...         ...
# 129088  MOV-0129089     14/9/2026  2026      9       Lunes
# 129089  MOV-0129090     14/9/2026  2026      9       Lunes
# 129090  MOV-0129091     14/9/2026  2026      9       Lunes
# 129091  MOV-0129092     14/9/2026  2026      9       Lunes
# 129092  MOV-0129093     14/9/2026  2026      9       Lunes
#
#                 movement_type movement_direction          reference_type  \
# 0        Transferencia Salida             Salida  Orden de Transferencia
# 1             Despacho a Mina             Salida          Pedido de Mina
# ...

# %%
    df.sort_values('month',ascending=False)
# Out:
#        movement_id movement_date  year  month day_of_week  \
# 50745  MOV-0050746     1/12/2024  2024     12     Domingo
# 50746  MOV-0050747     1/12/2024  2024     12     Domingo
# 50747  MOV-0050748     1/12/2024  2024     12     Domingo
# 50748  MOV-0050749     1/12/2024  2024     12     Domingo
# 50749  MOV-0050750     1/12/2024  2024     12     Domingo
# ...            ...           ...   ...    ...         ...
# 13802  MOV-0013803     26/1/2024  2024      1     Viernes
# 13803  MOV-0013804     26/1/2024  2024      1     Viernes
# 13804  MOV-0013805     26/1/2024  2024      1     Viernes
# 13805  MOV-0013806     26/1/2024  2024      1     Viernes
# 55379  MOV-0055380      8/1/2025  2025      1   Miércoles
#
#                movement_type movement_direction          reference_type  \
# 50745  Transferencia Entrada            Entrada  Orden de Transferencia
# 50746  Transferencia Entrada            Entrada  Orden de Transferencia
# ...

# %%
# Ordenar por multiples columnnas
df.sort_values(['month','year'],ascending=True)
# Out:
#        movement_id movement_date  year  month day_of_week  \
# 10568  MOV-0010569      1/1/2024  2024      1       Lunes
# 10569  MOV-0010570      1/1/2024  2024      1       Lunes
# 10570  MOV-0010571      1/1/2024  2024      1       Lunes
# 10571  MOV-0010572      1/1/2024  2024      1       Lunes
# 10572  MOV-0010573      1/1/2024  2024      1       Lunes
# ...            ...           ...   ...    ...         ...
# 98469  MOV-0098470    31/12/2025  2025     12   Miércoles
# 98470  MOV-0098471    31/12/2025  2025     12   Miércoles
# 98471  MOV-0098472    31/12/2025  2025     12   Miércoles
# 98472  MOV-0098473    31/12/2025  2025     12   Miércoles
# 98473  MOV-0098474    31/12/2025  2025     12   Miércoles
#
#                movement_type movement_direction          reference_type  \
# 10568        Despacho a Mina             Salida          Pedido de Mina
# 10569  Transferencia Entrada            Entrada  Orden de Transferencia
# ...

# %%
# Ordenar por multiples columnnas Y actualizar en el DF
df.sort_values(['month','year'],ascending=True, inplace=True)
df
# Out:
#        movement_id movement_date  year  month day_of_week  \
# 10568  MOV-0010569      1/1/2024  2024      1       Lunes
# 10569  MOV-0010570      1/1/2024  2024      1       Lunes
# 10570  MOV-0010571      1/1/2024  2024      1       Lunes
# 10571  MOV-0010572      1/1/2024  2024      1       Lunes
# 10572  MOV-0010573      1/1/2024  2024      1       Lunes
# ...            ...           ...   ...    ...         ...
# 98469  MOV-0098470    31/12/2025  2025     12   Miércoles
# 98470  MOV-0098471    31/12/2025  2025     12   Miércoles
# 98471  MOV-0098472    31/12/2025  2025     12   Miércoles
# 98472  MOV-0098473    31/12/2025  2025     12   Miércoles
# 98473  MOV-0098474    31/12/2025  2025     12   Miércoles
#
#                movement_type movement_direction          reference_type  \
# 10568        Despacho a Mina             Salida          Pedido de Mina
# 10569  Transferencia Entrada            Entrada  Orden de Transferencia
# ...

# %%
# Ordenar con funcion KEY
df.sort_values( ['day_of_week'] , ascending=True, key=lambda col:col.str.lower())
# Out:
#        movement_id movement_date  year  month day_of_week  \
# 11398  MOV-0011399      7/1/2024  2024      1     Domingo
# 11399  MOV-0011400      7/1/2024  2024      1     Domingo
# 11400  MOV-0011401      7/1/2024  2024      1     Domingo
# 11401  MOV-0011402      7/1/2024  2024      1     Domingo
# 11402  MOV-0011403      7/1/2024  2024      1     Domingo
# ...            ...           ...   ...    ...         ...
# 97936  MOV-0097937    26/12/2025  2025     12     Viernes
# 97937  MOV-0097938    26/12/2025  2025     12     Viernes
# 97938  MOV-0097939    26/12/2025  2025     12     Viernes
# 97939  MOV-0097940    26/12/2025  2025     12     Viernes
# 97940  MOV-0097941    26/12/2025  2025     12     Viernes
#
#                movement_type movement_direction          reference_type  \
# 11398    Recepción de Compra            Entrada         Orden de Compra
# 11399  Transferencia Entrada            Entrada  Orden de Transferencia
# ...
